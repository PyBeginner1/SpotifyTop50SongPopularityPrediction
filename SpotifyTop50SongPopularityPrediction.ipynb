# %% [markdown]
# <a href="https://colab.research.google.com/github/PyBeginner1/SpotifyTop50SongPopularityPrediction/blob/main/SpotifyTop50SongPopularityPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import plotly.express as px

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# %%
song = pd.read_csv('/content/top50.csv', encoding = 'latin-1')

# %%
song
# Out:
#     Unnamed: 0  ... Popularity
# 0            1  ...         79
# 1            2  ...         92
# 2            3  ...         85
# 3            4  ...         86
# 4            5  ...         94
# 5            6  ...         84
# 6            7  ...         92
# 7            8  ...         90
# 8            9  ...         87
# 9           10  ...         95
# 10          11  ...         93
# 11          12  ...         86
# 12          13  ...         88
# 13          14  ...         87
# 14          15  ...         92
# 15          16  ...         82
# 16          17  ...         90
# 17          18  ...         91
# 18          19  ...         88
# 19          20  ...         91
# 20          21  ...         91
# 21          22  ...         91
# 22          23  ...         83
# 23          24  ...         91
# 24          25  ...         89
# 25          26  ...         70
# 26          27  ...         83
# 27          28  ...         89
# 28          29  ...         91
# ...

# %%
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        50 non-null     int64
#  1   Track.Name        50 non-null     object
#  2   Artist.Name       50 non-null     object
#  3   Genre             50 non-null     object
#  4   Beats.Per.Minute  50 non-null     int64
#  5   Energy            50 non-null     int64
#  6   Danceability      50 non-null     int64
#  7   Loudness..dB..    50 non-null     int64
#  8   Liveness          50 non-null     int64
#  9   Valence.          50 non-null     int64
#  10  Length.           50 non-null     int64
#  11  Acousticness..    50 non-null     int64
#  12  Speechiness.      50 non-null     int64
#  13  Popularity        50 non-null     int64
# dtypes: int64(11), object(3)
# memory usage: 5.6+ KB

# %%
song.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute  ...  Speechiness.  Popularity
# count    50.00000         50.000000  ...     50.000000   50.000000
# mean     25.50000        120.060000  ...     12.480000   87.500000
# std      14.57738         30.898392  ...     11.161596    4.491489
# min       1.00000         85.000000  ...      3.000000   70.000000
# 25%      13.25000         96.000000  ...      5.000000   86.000000
# 50%      25.50000        104.500000  ...      7.000000   88.000000
# 75%      37.75000        137.500000  ...     15.000000   90.750000
# max      50.00000        190.000000  ...     46.000000   95.000000
#
# [8 rows x 11 columns]

# %% [markdown]
# Preprocessing

# %%
song = song.drop(['Unnamed: 0', 'Track.Name' ], axis = 1)

# %%
song
# Out:
#          Artist.Name             Genre  ...  Speechiness.  Popularity
# 0       Shawn Mendes      canadian pop  ...             3          79
# 1           Anuel AA    reggaeton flow  ...             9          92
# 2      Ariana Grande         dance pop  ...            46          85
# 3         Ed Sheeran               pop  ...            19          86
# 4        Post Malone           dfw rap  ...             7          94
# 5         Ed Sheeran               pop  ...             4          84
# 6          Lil Tecca        trap music  ...            29          92
# 7          Sam Smith               pop  ...             9          90
# 8          Lil Nas X       country rap  ...            10          87
# 9      Billie Eilish        electropop  ...            38          95
# 10         Bad Bunny         reggaeton  ...            31          93
# 11          DJ Snake         dance pop  ...             7          86
# ...

# %% [markdown]
# Seperating Popularity column by less & more popular using qcut which cuts based on mean

# %%
pd.qcut(song['Popularity'], q = 2, labels = ['Less Popular', 'More Popular'])
# Out:
# 0     Less Popular
# 1     More Popular
# 2     Less Popular
# 3     Less Popular
# 4     More Popular
# 5     Less Popular
# 6     More Popular
# 7     More Popular
# 8     Less Popular
# 9     More Popular
# 10    More Popular
# 11    Less Popular
# 12    Less Popular
# 13    Less Popular
# 14    More Popular
# 15    Less Popular
# 16    More Popular
# 17    More Popular
# 18    Less Popular
# 19    More Popular
# 20    More Popular
# 21    More Popular
# 22    Less Popular
# 23    More Popular
# 24    More Popular
# 25    Less Popular
# 26    Less Popular
# 27    More Popular
# 28    More Popular
# 29    More Popular
# 30    Less Popular
# 31    More Popular
# 32    More Popular
# 33    More Popular
# 34    More Popular
# 35    More Popular
# 36    More Popular
# 37    Less Popular
# 38    Less Popular
# 39    Less Popular
# 40    Less Popular
# 41    More Popular
# 42    Less Popular
# 43    Less Popular
# 44    Less Popular
# 45    Less Popular
# 46    Less Popular
# ...

# %%
pd.qcut(song['Popularity'], q = 2, labels = [0, 1])
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    1
# 15    0
# 16    1
# 17    1
# 18    0
# 19    1
# 20    1
# 21    1
# 22    0
# 23    1
# 24    1
# 25    0
# 26    0
# 27    1
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    1
# 35    1
# 36    1
# 37    0
# 38    0
# 39    0
# 40    0
# 41    1
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# Name: Popularity, dtype: category
# Categories (2, int64): [0 < 1]

# %%
song['Popularity'] = pd.qcut(song['Popularity'], q = 2, labels = [0, 1])

# %%
song.head()
# Out:
#      Artist.Name           Genre  ...  Speechiness.  Popularity
# 0   Shawn Mendes    canadian pop  ...             3           0
# 1       Anuel AA  reggaeton flow  ...             9           1
# 2  Ariana Grande       dance pop  ...            46           0
# 3     Ed Sheeran             pop  ...            19           0
# 4    Post Malone         dfw rap  ...             7           1
#
# [5 rows x 12 columns]

# %% [markdown]
# **One Hot Encoding**

# %%
def onehot_encode(df, column, prefix):
    df = df.copy()
    dummies = pd.get_dummies(df[column], prefix=prefix)
    df = pd.concat([df, dummies], axis=1)
    df = df.drop(column, axis=1)
    return df

# %%
song = onehot_encode(song, 'Genre', 'genre')
song = onehot_encode(song, 'Artist.Name', 'artist')

# %%
song.head()
# Out:
#    Beats.Per.Minute  Energy  ...  artist_Y2K  artist_Young Thug
# 0               117      55  ...           0                  0
# 1               105      81  ...           0                  0
# 2               190      80  ...           0                  0
# 3                93      65  ...           0                  0
# 4               150      65  ...           0                  0
#
# [5 rows x 69 columns]

# %% [markdown]
# Splitting & Scaling the data

# %%
X = song.drop('Popularity', axis =1)
Y = song['Popularity']

# %%
X
# Out:
#     Beats.Per.Minute  Energy  ...  artist_Y2K  artist_Young Thug
# 0                117      55  ...           0                  0
# 1                105      81  ...           0                  0
# 2                190      80  ...           0                  0
# 3                 93      65  ...           0                  0
# 4                150      65  ...           0                  0
# 5                102      68  ...           0                  0
# 6                180      64  ...           0                  0
# 7                111      68  ...           0                  0
# 8                136      62  ...           0                  0
# 9                135      43  ...           0                  0
# 10               176      62  ...           0                  0
# 11                96      71  ...           0                  0
# 12               110      41  ...           0                  0
# ...

# %%
Y
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     1
# 5     0
# 6     1
# 7     1
# 8     0
# 9     1
# 10    1
# 11    0
# 12    0
# 13    0
# 14    1
# 15    0
# 16    1
# 17    1
# 18    0
# 19    1
# 20    1
# 21    1
# 22    0
# 23    1
# 24    1
# 25    0
# 26    0
# 27    1
# 28    1
# 29    1
# 30    0
# 31    1
# 32    1
# 33    1
# 34    1
# 35    1
# 36    1
# 37    0
# 38    0
# 39    0
# 40    0
# 41    1
# 42    0
# 43    0
# 44    0
# 45    0
# 46    0
# 47    0
# 48    0
# 49    0
# Name: Popularity, dtype: category
# Categories (2, int64): [0 < 1]

# %% [markdown]
# Scaling

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)

# %% [markdown]
# Train & Test Split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size =0.3, random_state = 20)

# %%
X.shape,X_train.shape, X_test.shape
# Out:
# ((50, 68), (35, 68), (15, 68))

# %% [markdown]
# Model

# %%
models = {
    'Logistic Regression' : LogisticRegression(),
    'K-Neighbors' : KNeighborsClassifier(),
    'Decision Tree' : DecisionTreeClassifier(),
    'Neural Network' : MLPClassifier(),
    'SVM' : SVC()
}

for name, model in models.items():
  model.fit(X_train, Y_train)
  print(name +' trained')
# Out:
# Logistic Regression trained
# K-Neighbors trained
# Decision Tree trained
# Neural Network trained
# SVM trained

# %%
for name, model in models.items():
  results = model.score(X_test, Y_test)
  print(name + ' : {:.2f}%'.format(results * 100))
# Out:
# Logistic Regression : 73.33%
# K-Neighbors : 53.33%
# Decision Tree : 40.00%
# Neural Network : 60.00%
# SVM : 73.33%

# %%
log_model = LogisticRegression()
knn_model = KNeighborsClassifier()
dec_model = DecisionTreeClassifier()
mlp_model = MLPClassifier()
svm_model = SVC()

# %%
log_model.fit(X_train, Y_train)
knn_model.fit(X_train, Y_train)
dec_model.fit(X_train, Y_train)
mlp_model.fit(X_train, Y_train)
svm_model.fit(X_train, Y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
log_acc = log_model.score(X_test, Y_test)
knn_acc = knn_model.score(X_test, Y_test)
dec_acc = dec_model.score(X_test, Y_test)
mlp_acc = mlp_model.score(X_test, Y_test)
svm_acc = svm_model.score(X_test, Y_test)

# %%
print("Logistic Regression Accuracy: {:.2f}%".format(log_acc * 100))
print("K-Nearest-Neighbors Accuracy: {:.2f}%".format(knn_acc * 100))
print("Decision Tree Accuracy: {:.2f}%".format(dec_acc * 100))
print("Neural Network Accuracy: {:.2f}%".format(mlp_acc * 100))
print("Support Vector Machine Accuracy: {:.2f}".format(svm_acc * 100))
# Out:
# Logistic Regression Accuracy: 73.33%
# K-Nearest-Neighbors Accuracy: 53.33%
# Decision Tree Accuracy: 40.00%
# Neural Network Accuracy: 73.33%
# Support Vector Machine Accuracy: 73.33

# %%
fig = px.bar(
    x=["Logistic Regression", "K-Nearest-Neighbors", "Decision Tree", "Neural Network", "Support Vector Machine"],
    y=[log_acc, knn_acc, dec_acc, mlp_acc, svm_acc],
    color=["Logistic Regression", "K-Nearest-Neighbors", "Decision Tree", "Neural Network", "Support Vector Machine"],
    labels={'x': "Model", 'y': "Accuracy"},
    title="Model Accuracy Comparison"
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a36bc4fc-7315-43d9-b70b-d06e7f02783b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a36bc4fc-7315-43d9-b70b-d06e7f02783b")) {
#                     Plotly.newPlot(
#                         'a36bc4fc-7315-43d9-b70b-d06e7f02783b',
# ...
